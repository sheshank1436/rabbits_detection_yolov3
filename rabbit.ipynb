# %% [markdown]
# <a href="https://colab.research.google.com/github/sheshank1436/rabbits_detection_yolov3/blob/main/rabbit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Check if NVIDIA GPU is enabled
# !nvidia-smi
# Out:
# Mon Jan 25 15:50:57 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P8    29W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# ln: failed to create symbolic link '/mydrive/My Drive': File exists
# 'Colab Notebooks'     'My Drive'   yolov3
#  darknet-master        yolo	   YOLOV3_weights
# 'darknet-master (1)'   yolo1	   YOLOV4__weights

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
# change makefile to have GPU and OPENCV enabled
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# !make
# Out:
# /content/darknet
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %%
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# !echo "rabbit" > data/obj.names
# !echo -e 'classes= 1\ntrain  = data/train.txt\nvalid  = data/test.txt\nnames = data/obj.names\nbackup = /mydrive/yolo1' > data/obj.data
# !mkdir data/obj
# Out:
# mkdir: cannot create directory ‘data/obj’: File exists

# %%
# Download weights darknet model 53
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-01-25 15:53:02--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74.1’
#
# darknet53.conv.74.1 100%[===================>] 154.96M   846KB/s    in 4m 22s
#
# 2021-01-25 15:57:24 (606 KB/s) - ‘darknet53.conv.74.1’ saved [162482580/162482580]

# %%
# !unzip /mydrive/yolo1/images.zip -d data/obj
# Out:
# Archive:  /mydrive/yolo1/images.zip
# replace data/obj/images/classes.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/obj/images/rabbit0.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/obj/images/rabbit0.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/obj/images/rabbit1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace data/obj/images/rabbit1.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# We're going to convert the class index on the .txt files. As we're working with only one class, it's supposed to be class 0.
# If the index is different from 0 then we're going to change it.
import glob
import os
import re

txt_file_paths = glob.glob(r"/content/darknet/data/obj/images/*.txt")
for i, file_path in enumerate(txt_file_paths):
    # get image size
    with open(file_path, "r") as f_o:
        lines = f_o.readlines()

        text_converted = []
        for line in lines:
            print(line)
            numbers = re.findall("[0-9.]+", line)
            print(numbers)
            if numbers:

                # Define coordinates
                text = "{} {} {} {} {}".format(0, numbers[1], numbers[2], numbers[3], numbers[4])
                text_converted.append(text)
                print(i, file_path)
                print(text)
        # Write file
        with open(file_path, 'w') as fp:
            for item in text_converted:
                fp.writelines("%s\n" % item)
# Out:
# 0 0.361818 0.489071 0.658182 0.464481
#
# ['0', '0.361818', '0.489071', '0.658182', '0.464481']
# 0 /content/darknet/data/obj/images/rabbit88.txt
# 0 0.361818 0.489071 0.658182 0.464481
# 0 0.376667 0.485119 0.526667 0.755952
#
# ['0', '0.376667', '0.485119', '0.526667', '0.755952']
# 1 /content/darknet/data/obj/images/rabbit98.txt
# 0 0.376667 0.485119 0.526667 0.755952
# 0 0.746094 0.517766 0.218750 0.751269
#
# ['0', '0.746094', '0.517766', '0.218750', '0.751269']
# 2 /content/darknet/data/obj/images/rabbit147.txt
# 0 0.746094 0.517766 0.218750 0.751269
# 0 0.572727 0.494536 0.665455 0.825137
#
# ['0', '0.572727', '0.494536', '0.665455', '0.825137']
# 4 /content/darknet/data/obj/images/rabbit41.txt
# 0 0.572727 0.494536 0.665455 0.825137
# 0 0.358182 0.516393 0.650909 0.508197
#
# ['0', '0.358182', '0.516393', '0.650909', '0.508197']
# 5 /content/darknet/data/obj/images/rabbit11.txt
# 0 0.358182 0.516393 0.650909 0.508197
# 0 0.218500 0.594453 0.431000 0.772114
#
# ...

# %%
import glob
images_list = glob.glob("/content/darknet/data/obj/images/*.jpg")
print(images_list)
# Out:
# ['/content/darknet/data/obj/images/rabbit93.jpg', '/content/darknet/data/obj/images/rabbit107.jpg', '/content/darknet/data/obj/images/rabbit41.jpg', '/content/darknet/data/obj/images/rabbit140.jpg', '/content/darknet/data/obj/images/rabbit39.jpg', '/content/darknet/data/obj/images/rabbit131.jpg', '/content/darknet/data/obj/images/rabbit4.jpg', '/content/darknet/data/obj/images/rabbit59.jpg', '/content/darknet/data/obj/images/rabbit29.jpg', '/content/darknet/data/obj/images/rabbit6.jpg', '/content/darknet/data/obj/images/rabbit67.jpg', '/content/darknet/data/obj/images/rabbit121.jpg', '/content/darknet/data/obj/images/rabbit94.jpg', '/content/darknet/data/obj/images/rabbit117.jpg', '/content/darknet/data/obj/images/rabbit56.jpg', '/content/darknet/data/obj/images/rabbit26.jpg', '/content/darknet/data/obj/images/rabbit75.jpg', '/content/darknet/data/obj/images/rabbit30.jpg', '/content/darknet/data/obj/images/rabbit92.jpg', '/content/darknet/data/obj/images/rabbit70.jpg', '/content/dark
# ...

# %%
#Create training.txt file
file = open("data/train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %%
# Start the training
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 10010 (10010), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_training
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
# ...
